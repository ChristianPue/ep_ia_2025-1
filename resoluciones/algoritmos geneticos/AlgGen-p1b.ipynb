# %%
import random

# %%
# Crear individuo
def create_individual_random(n):
  # Genera un individuo válido (solución candidata) sin repetir columnas
  # Permutación aleatoria de las columnas
  return [random.randint(0, n - 1) for _ in range(n)]

# %%
# Fitness
def fitness(n, individual):
  conflicts = 0

  for i in range(n):
    for j in range (i + 1, n): # Solo se compara cada par una vez
      # Conflicto por estar en la misma columna
      if individual[i] == individual[j]:
        conflicts += 1
      
      # Conflicto por estar en la misma diagonal
      if abs(individual[i] - individual[j]) == abs(i - j):
        conflicts += 1
  
  # Se devuelve el valor negativo porque el algoritmo busca maximizar la idoneidad (fitness).
  # Se quiere ver que individuo aumenta acercándose más a 0
  return -conflicts

# %%
# Selección
def selection(n, population):
  # Selección aleatoria de candidatos:
  # Se eligen 5 individuos al azar de la población 
  tournament = random.sample(population, 5)
  # Ordena los participantes de mejor a peor según su función fitness
  tournament.sort(key=lambda x: fitness(n, x), reverse=True)
  # Devuelve el individuo más apto
  return tournament[0]

def selection_rankbased(n, population):
  # Ordenar de mejor (más cercano a 0) a peor
  sorted_population = sorted(population, key=lambda x: fitness(n, x), reverse=True)

  # Asignar pesos de selección según el ranking
  # El mejor tiene peso mayor (ej: N, N-1, ..., 1)
  ranks = list(range(len(population), 0, -1))

  # Selección probabilística según ranking
  selected = random.choices(sorted_population, weights=ranks, k=1)[0]

  return selected

# %%
# Crossover
def crossover(n, parent1, parent2):
  # Elegir un punto de corte aleatorio en el rango (1, n-2) 
  # para evitar cortes extremos
  cut = random.randint(1, n - 2)
  # Crear el hijo tomando parte de parent1 hasta 'cut' 
  # y el resto de parent2
  child = parent1[:cut] + parent2[cut:]
  return child

# %%
# Mutación
def mutate(n, mutation_rate, individual):
  # Se ejecuta la mutación solo si el valor aleatorio 
  # está dentro de mutation_rate
  if random.random() < mutation_rate:
    # Selecciona un índice aleatorio para mutar
    idx = random.randint(0, n - 1)
    # Modifica el valor con otro aleatorio
    individual[idx] = random.randint(0, n - 1)
  
  return individual

# %%
# Función principal - Algoritmo Genético
def genetic_algorithm_random(n, population_size, max_generations, mutation_rate):
  # Definir la población
  population = [create_individual_random(n) for _ in range(population_size)]

  # Creación de generaciones hasta max_generations
  for generation in range(max_generations):
    # Ordenar la población según el fitness
    population.sort(key=lambda x: fitness(n, x), reverse=True)
    # Seleccionar el mejor genoma de la población
    best = population[0]
    # Mostrar el fitness de cada generación
    print(f"Generación {generation}: Fitness = {fitness(n, best)}")

    # Si el mejor individuo llego a 0. Es el elegido
    if fitness(n, best) == 0:
      print(f"¡Solución encontrada!: {best}")
      return best
    
    # Creación de la siguiente generación
    next_generation = []

    while len(next_generation) < population_size:
      # Primer Padre
      parent1 = selection(n, population)
      # Segundo Padre
      parent2 = selection(n, population)
      
      # Crear hijo mediante crossover
      child = crossover(n, parent1, parent2)
      
      # Mutación
      child = mutate(n, mutation_rate, child)

      next_generation.append(child)

    # Reemplazar
    population = next_generation

  print("No se encontró solución.")
  return None

# %%
N = 8
POPULATION_SIZE = 100
MAX_GENERATIONS = 10000000
MUTATION_RATE = 0.05

solution = genetic_algorithm_random(N, POPULATION_SIZE, MAX_GENERATIONS, MUTATION_RATE)
# Out:
# Generación 0: Fitness = -4
# Generación 1: Fitness = -2
# Generación 2: Fitness = -2
# Generación 3: Fitness = -1
# Generación 4: Fitness = -1
# Generación 5: Fitness = -1
# Generación 6: Fitness = -1
# Generación 7: Fitness = -1
# Generación 8: Fitness = -1
# Generación 9: Fitness = -1
# Generación 10: Fitness = -1
# Generación 11: Fitness = -1
# Generación 12: Fitness = -1
# Generación 13: Fitness = -1
# Generación 14: Fitness = -1
# Generación 15: Fitness = -1
# Generación 16: Fitness = -1
# Generación 17: Fitness = -1
# Generación 18: Fitness = -1
# Generación 19: Fitness = -1
# Generación 20: Fitness = -1
# Generación 21: Fitness = -1
# Generación 22: Fitness = -1
# Generación 23: Fitness = -1
# Generación 24: Fitness = -1
# Generación 25: Fitness = -1
# Generación 26: Fitness = -1
# Generación 27: Fitness = -1
# Generación 28: Fitness = -1
# Generación 29: Fitness = -1
# Generación 30: Fitness = -1
# Generación 31: Fitness = -1
# Generación 32: Fitness = -1
# Generación 33: Fitness = -1
# Generación 34: Fitness = -1
# Generación 35: Fitness = -1
# Generación 36: Fitness = -1
# Generación 37: Fitness = -1
# Generación 38: Fitness = -1
# Generación 39: Fitness = -1
# Generación 40: Fitness = -1
# Generación 41: Fitness = -1
# Generación 42: Fitness = -1
# Generación 43: Fitness = -1
# Generación 44: Fitness = -1
# Generación 45: Fitness = -1
# Generación 46: Fitness = -1
# Generación 47: Fitness = -1
# Generación 48: Fitness = -1
# Generación 49: Fitness = -1
# Generación 50: Fitness = -1
# Generación 51: Fitness = -1
# Generación 52: Fitness = -1
# Generación 53: Fitness = -1
# Generación 54: Fitness = -1
# Generación 55: Fitness = -1
# Generación 56: Fitness = -1
# Generación 57: Fitness = -1
# Generación 58: Fitness = -1
# Generación 59: Fitness = -1
# Generación 60: Fitness = -1
# Generación 61: Fitness = -1
# Generación 62: Fitness = -1
# Generación 63: Fitness = -1
# Generación 64: Fitness = -1
# Generación 65: Fitness = -1
# Generación 66: Fitness = -1
# Generación 67: Fitness = -1
# Generación 68: Fitness = -1
# Generación 69: Fitness = -1
# Generación 70: Fitness = -1
# Generación 71: Fitness = -1
# Generación 72: Fitness = -1
# Generación 73: Fitness = -1
# Generación 74: Fitness = -1
# Generación 75: Fitness = -1
# Generación 76: Fitness = -1
# Generación 77: Fitness = -1
# Generación 78: Fitness = -1
# Generación 79: Fitness = -1
# Generación 80: Fitness = -1
# Generación 81: Fitness = -1
# Generación 82: Fitness = -1
# Generación 83: Fitness = -1
# Generación 84: Fitness = -1
# Generación 85: Fitness = -1
# Generación 86: Fitness = -1
# Generación 87: Fitness = -1
# Generación 88: Fitness = -1
# Generación 89: Fitness = -1
# Generación 90: Fitness = -1
# Generación 91: Fitness = -1
# Generación 92: Fitness = -1
# Generación 93: Fitness = -1
# Generación 94: Fitness = -1
# Generación 95: Fitness = -1
# Generación 96: Fitness = -1
# Generación 97: Fitness = -1
# Generación 98: Fitness = -1
# Generación 99: Fitness = -1
# Generación 100: Fitness = -1
# Generación 101: Fitness = -1
# Generación 102: Fitness = -1
# Generación 103: Fitness = -1
# Generación 104: Fitness = -1
# Generación 105: Fitness = -1
# Generación 106: Fitness = -1
# Generación 107: Fitness = -1
# Generación 108: Fitness = -1
# Generación 109: Fitness = -1
# Generación 110: Fitness = -1
# Generación 111: Fitness = -1
# Generación 112: Fitness = -1
# Generación 113: Fitness = -1
# Generación 114: Fitness = -1
# Generación 115: Fitness = -1
# Generación 116: Fitness = -1
# Generación 117: Fitness = -1
# Generación 118: Fitness = -1
# Generación 119: Fitness = -1
# Generación 120: Fitness = -1
# Generación 121: Fitness = -1
# Generación 122: Fitness = -1
# Generación 123: Fitness = -1
# Generación 124: Fitness = -1
# Generación 125: Fitness = -1
# Generación 126: Fitness = -1
# Generación 127: Fitness = -1
# Generación 128: Fitness = -1
# Generación 129: Fitness = -1
# Generación 130: Fitness = -1
# Generación 131: Fitness = -1
# Generación 132: Fitness = -1
# Generación 133: Fitness = -1
# Generación 134: Fitness = -1
# Generación 135: Fitness = -1
# Generación 136: Fitness = -1
# Generación 137: Fitness = -1
# Generación 138: Fitness = -1
# Generación 139: Fitness = -1
# Generación 140: Fitness = -1
# Generación 141: Fitness = -1
# Generación 142: Fitness = -1
# Generación 143: Fitness = -1
# Generación 144: Fitness = -1
# Generación 145: Fitness = -1
# Generación 146: Fitness = -1
# Generación 147: Fitness = -1
# Generación 148: Fitness = -1
# Generación 149: Fitness = -1
# Generación 150: Fitness = -1
# Generación 151: Fitness = -1
# Generación 152: Fitness = -1
# Generación 153: Fitness = -1
# Generación 154: Fitness = -1
# Generación 155: Fitness = -1
# Generación 156: Fitness = -1
# Generación 157: Fitness = -1
# Generación 158: Fitness = -1
# Generación 159: Fitness = -1
# Generación 160: Fitness = -1
# Generación 161: Fitness = -1
# Generación 162: Fitness = -1
# Generación 163: Fitness = -1
# Generación 164: Fitness = -1
# Generación 165: Fitness = -1
# Generación 166: Fitness = -1
# Generación 167: Fitness = -1
# Generación 168: Fitness = -1
# Generación 169: Fitness = -1
# Generación 170: Fitness = -1
# Generación 171: Fitness = -1
# Generación 172: Fitness = -1
# Generación 173: Fitness = -1
# Generación 174: Fitness = -1
# Generación 175: Fitness = -1
# Generación 176: Fitness = -1
# Generación 177: Fitness = -1
# Generación 178: Fitness = -1
# Generación 179: Fitness = -1
# Generación 180: Fitness = -1
# Generación 181: Fitness = -1
# Generación 182: Fitness = -1
# Generación 183: Fitness = -1
# Generación 184: Fitness = -1
# Generación 185: Fitness = -1
# Generación 186: Fitness = -1
# Generación 187: Fitness = -1
# Generación 188: Fitness = -1
# Generación 189: Fitness = -1
# Generación 190: Fitness = -1
# Generación 191: Fitness = -1
# Generación 192: Fitness = -1
# Generación 193: Fitness = -1
# Generación 194: Fitness = -1
# Generación 195: Fitness = -1
# Generación 196: Fitness = -1
# Generación 197: Fitness = -1
# Generación 198: Fitness = -1
# Generación 199: Fitness = -1
# Generación 200: Fitness = -1
# Generación 201: Fitness = -1
# Generación 202: Fitness = -1
# Generación 203: Fitness = 0
# ¡Solución encontrada!: [3, 1, 4, 7, 5, 0, 2, 6]

# %%
# Mostrar la solución en un tablero NxN
def view_solution(solution):
  print("Tablero (representación de filas por columna):")
  # Indices: 0 1 2 ...
  print("   ", end="")
  for i in range(len(solution)):
    print(f"{i}", end=" ")
  print("")

  for i in range(len(solution)):
    row = ['Q' if solution[i] == j else '.' for j in range(len(solution))]
    print(f" {i} ", end="")
    print(" ".join(row))
  
  print(f"Solución (cromosoma): {solution}")

# %%
view_solution(solution)
# Out:
# Tablero (representación de filas por columna):
#    0 1 2 3 4 5 6 7
#  0 . . . Q . . . .
#  1 . Q . . . . . .
#  2 . . . . Q . . .
#  3 . . . . . . . Q
#  4 . . . . . Q . .
#  5 Q . . . . . . .
#  6 . . Q . . . . .
#  7 . . . . . . Q .
# Solución (genoma): [3, 1, 4, 7, 5, 0, 2, 6]

# %%
def genetic_algorithm_param(n, population, max_generations, mutation_rate):
  if len(population) < 2:
    raise ValueError("La población inicial debe tener al menos 2 individuos.")

  # Definir la cantidad de la población
  population_size = len(population)
  
  # Creación de generaciones hasta max_generations
  for generation in range(max_generations):
    # Ordenar la población según el fitness
    population.sort(key=lambda x: fitness(n, x), reverse=True)
    # Seleccionar el mejor genoma de la población
    best = population[0]
    # Mostrar el fitness de cada generación
    print(f"Generación {generation}: Fitness = {fitness(n, best)}")

    # Si el mejor individuo llego a 0. Es el elegido
    if fitness(n, best) == 0:
      print(f"¡Solución encontrada!: {best}")
      return best
    
    # Creación de la siguiente generación
    next_generation = []

    while len(next_generation) < population_size:
      # Primer Padre
      parent1 = selection_rankbased(n, population)
      # Segundo Padre
      parent2 = selection_rankbased(n, population)
      
      # Crear hijo mediante crossover
      child = crossover(n, parent1, parent2)
      
      # Mutación
      child = mutate(n, mutation_rate, child)

      next_generation.append(child)

    # Reemplazar
    population = next_generation

  print("No se encontró solución.")
  return None

# %%
N = 8
MAX_GENERATIONS = 10000000
MUTATION_RATE = 0.05

INITIAL_POPULATION = [
  [6, 0, 7, 3, 6, 1, 5, 2],
  [3, 2, 0, 5, 6, 3, 5, 1],
  [4, 0, 5, 3, 1, 1, 7, 2],
  [0, 0, 6, 2, 4, 1, 7, 5]
]

solution = genetic_algorithm_param(N, INITIAL_POPULATION, MAX_GENERATIONS, MUTATION_RATE)
# Out:
# Generación 0: Fitness = -2
# Generación 1: Fitness = -2
# Generación 2: Fitness = -2
# Generación 3: Fitness = -2
# Generación 4: Fitness = -2
# Generación 5: Fitness = -2
# Generación 6: Fitness = -2
# Generación 7: Fitness = -2
# Generación 8: Fitness = -2
# Generación 9: Fitness = -2
# Generación 10: Fitness = -2
# Generación 11: Fitness = -2
# Generación 12: Fitness = -2
# Generación 13: Fitness = -2
# Generación 14: Fitness = -2
# Generación 15: Fitness = -2
# Generación 16: Fitness = -2
# Generación 17: Fitness = -2
# Generación 18: Fitness = -2
# Generación 19: Fitness = -2
# Generación 20: Fitness = -2
# Generación 21: Fitness = -2
# Generación 22: Fitness = -2
# Generación 23: Fitness = -2
# Generación 24: Fitness = -2
# Generación 25: Fitness = -2
# Generación 26: Fitness = -2
# Generación 27: Fitness = -2
# Generación 28: Fitness = -2
# Generación 29: Fitness = -2
# Generación 30: Fitness = -2
# Generación 31: Fitness = -2
# Generación 32: Fitness = -2
# Generación 33: Fitness = -2
# Generación 34: Fitness = -2
# Generación 35: Fitness = -2
# Generación 36: Fitness = -2
# Generación 37: Fitness = -2
# Generación 38: Fitness = -1
# Generación 39: Fitness = -1
# Generación 40: Fitness = -1
# Generación 41: Fitness = -1
# Generación 42: Fitness = -1
# Generación 43: Fitness = -1
# Generación 44: Fitness = -1
# Generación 45: Fitness = -1
# Generación 46: Fitness = -1
# Generación 47: Fitness = -1
# Generación 48: Fitness = -1
# Generación 49: Fitness = -1
# Generación 50: Fitness = -1
# Generación 51: Fitness = -1
# Generación 52: Fitness = -1
# Generación 53: Fitness = -1
# Generación 54: Fitness = -1
# Generación 55: Fitness = -1
# Generación 56: Fitness = -1
# Generación 57: Fitness = -1
# Generación 58: Fitness = -1
# Generación 59: Fitness = -1
# Generación 60: Fitness = -1
# Generación 61: Fitness = -1
# Generación 62: Fitness = -1
# Generación 63: Fitness = -1
# Generación 64: Fitness = -1
# Generación 65: Fitness = -1
# Generación 66: Fitness = -1
# Generación 67: Fitness = -1
# Generación 68: Fitness = -1
# Generación 69: Fitness = -1
# Generación 70: Fitness = -1
# Generación 71: Fitness = -1
# Generación 72: Fitness = -1
# Generación 73: Fitness = -1
# Generación 74: Fitness = -1
# Generación 75: Fitness = -1
# Generación 76: Fitness = -1
# Generación 77: Fitness = -1
# Generación 78: Fitness = -1
# Generación 79: Fitness = -1
# Generación 80: Fitness = -1
# Generación 81: Fitness = -1
# Generación 82: Fitness = -1
# Generación 83: Fitness = -1
# Generación 84: Fitness = -1
# Generación 85: Fitness = -1
# Generación 86: Fitness = -1
# Generación 87: Fitness = -1
# Generación 88: Fitness = -1
# Generación 89: Fitness = -1
# Generación 90: Fitness = -1
# Generación 91: Fitness = -1
# Generación 92: Fitness = -1
# Generación 93: Fitness = -1
# Generación 94: Fitness = -1
# Generación 95: Fitness = -1
# Generación 96: Fitness = -1
# Generación 97: Fitness = -1
# Generación 98: Fitness = -1
# Generación 99: Fitness = -1
# Generación 100: Fitness = -1
# Generación 101: Fitness = -1
# Generación 102: Fitness = -1
# Generación 103: Fitness = -1
# Generación 104: Fitness = -1
# Generación 105: Fitness = -1
# Generación 106: Fitness = -1
# Generación 107: Fitness = -1
# Generación 108: Fitness = -1
# Generación 109: Fitness = -1
# Generación 110: Fitness = -1
# Generación 111: Fitness = -1
# Generación 112: Fitness = -1
# Generación 113: Fitness = -1
# Generación 114: Fitness = -1
# Generación 115: Fitness = -1
# Generación 116: Fitness = -1
# Generación 117: Fitness = -1
# Generación 118: Fitness = -1
# Generación 119: Fitness = -1
# Generación 120: Fitness = -1
# Generación 121: Fitness = -1
# Generación 122: Fitness = -1
# Generación 123: Fitness = -1
# Generación 124: Fitness = -1
# Generación 125: Fitness = -1
# Generación 126: Fitness = -1
# Generación 127: Fitness = -1
# Generación 128: Fitness = -1
# Generación 129: Fitness = -1
# Generación 130: Fitness = -1
# Generación 131: Fitness = -1
# Generación 132: Fitness = -1
# Generación 133: Fitness = -1
# Generación 134: Fitness = -1
# Generación 135: Fitness = -1
# Generación 136: Fitness = -1
# Generación 137: Fitness = -1
# Generación 138: Fitness = -1
# Generación 139: Fitness = -1
# Generación 140: Fitness = -1
# Generación 141: Fitness = -1
# Generación 142: Fitness = -1
# Generación 143: Fitness = -1
# Generación 144: Fitness = -1
# Generación 145: Fitness = -1
# Generación 146: Fitness = -1
# Generación 147: Fitness = -1
# Generación 148: Fitness = -1
# Generación 149: Fitness = -1
# Generación 150: Fitness = -1
# Generación 151: Fitness = -1
# Generación 152: Fitness = -1
# Generación 153: Fitness = -1
# Generación 154: Fitness = -1
# Generación 155: Fitness = -1
# Generación 156: Fitness = -1
# Generación 157: Fitness = -1
# Generación 158: Fitness = -1
# Generación 159: Fitness = -1
# Generación 160: Fitness = -1
# Generación 161: Fitness = -1
# Generación 162: Fitness = -1
# Generación 163: Fitness = -1
# Generación 164: Fitness = -1
# Generación 165: Fitness = -1
# Generación 166: Fitness = -1
# Generación 167: Fitness = -1
# Generación 168: Fitness = -1
# Generación 169: Fitness = -1
# Generación 170: Fitness = -1
# Generación 171: Fitness = -1
# Generación 172: Fitness = -1
# Generación 173: Fitness = -1
# Generación 174: Fitness = -1
# Generación 175: Fitness = -1
# Generación 176: Fitness = -1
# Generación 177: Fitness = -1
# Generación 178: Fitness = -1
# Generación 179: Fitness = -1
# Generación 180: Fitness = -1
# Generación 181: Fitness = -1
# Generación 182: Fitness = -1
# Generación 183: Fitness = -1
# Generación 184: Fitness = -1
# Generación 185: Fitness = -1
# Generación 186: Fitness = -1
# Generación 187: Fitness = -1
# Generación 188: Fitness = -1
# Generación 189: Fitness = -1
# Generación 190: Fitness = -1
# Generación 191: Fitness = -1
# Generación 192: Fitness = -1
# Generación 193: Fitness = -1
# Generación 194: Fitness = -1
# Generación 195: Fitness = -1
# Generación 196: Fitness = -1
# Generación 197: Fitness = -1
# Generación 198: Fitness = -1
# Generación 199: Fitness = -1
# Generación 200: Fitness = -1
# Generación 201: Fitness = -1
# Generación 202: Fitness = -1
# Generación 203: Fitness = -1
# Generación 204: Fitness = -1
# Generación 205: Fitness = -1
# Generación 206: Fitness = -1
# Generación 207: Fitness = -1
# Generación 208: Fitness = -1
# Generación 209: Fitness = -1
# Generación 210: Fitness = -1
# Generación 211: Fitness = -1
# Generación 212: Fitness = -1
# Generación 213: Fitness = -1
# Generación 214: Fitness = -1
# Generación 215: Fitness = -1
# Generación 216: Fitness = -1
# Generación 217: Fitness = -1
# Generación 218: Fitness = -1
# Generación 219: Fitness = -1
# Generación 220: Fitness = -1
# Generación 221: Fitness = -1
# Generación 222: Fitness = -1
# Generación 223: Fitness = -1
# Generación 224: Fitness = -1
# Generación 225: Fitness = -1
# Generación 226: Fitness = -1
# Generación 227: Fitness = -1
# Generación 228: Fitness = -1
# Generación 229: Fitness = -1
# Generación 230: Fitness = -1
# Generación 231: Fitness = -1
# Generación 232: Fitness = -1
# Generación 233: Fitness = -1
# Generación 234: Fitness = -1
# Generación 235: Fitness = -1
# Generación 236: Fitness = -1
# Generación 237: Fitness = -1
# Generación 238: Fitness = -1
# Generación 239: Fitness = -1
# Generación 240: Fitness = -1
# Generación 241: Fitness = -1
# Generación 242: Fitness = -1
# Generación 243: Fitness = -1
# Generación 244: Fitness = -1
# Generación 245: Fitness = -1
# Generación 246: Fitness = -1
# Generación 247: Fitness = -1
# Generación 248: Fitness = -1
# Generación 249: Fitness = -1
# Generación 250: Fitness = -1
# Generación 251: Fitness = -1
# Generación 252: Fitness = -1
# Generación 253: Fitness = -1
# Generación 254: Fitness = -1
# Generación 255: Fitness = -1
# Generación 256: Fitness = -1
# Generación 257: Fitness = -1
# Generación 258: Fitness = -1
# Generación 259: Fitness = -1
# Generación 260: Fitness = -1
# Generación 261: Fitness = -1
# Generación 262: Fitness = -1
# Generación 263: Fitness = -1
# Generación 264: Fitness = -1
# Generación 265: Fitness = -1
# Generación 266: Fitness = -1
# Generación 267: Fitness = -1
# Generación 268: Fitness = -1
# Generación 269: Fitness = -1
# Generación 270: Fitness = -1
# Generación 271: Fitness = -1
# Generación 272: Fitness = -1
# Generación 273: Fitness = -1
# Generación 274: Fitness = -1
# Generación 275: Fitness = -1
# Generación 276: Fitness = -1
# Generación 277: Fitness = -1
# Generación 278: Fitness = -1
# Generación 279: Fitness = -1
# Generación 280: Fitness = -1
# Generación 281: Fitness = -1
# Generación 282: Fitness = -1
# Generación 283: Fitness = -1
# Generación 284: Fitness = -1
# Generación 285: Fitness = -1
# Generación 286: Fitness = -1
# Generación 287: Fitness = -1
# Generación 288: Fitness = -1
# Generación 289: Fitness = -1
# Generación 290: Fitness = -1
# Generación 291: Fitness = -1
# Generación 292: Fitness = -1
# Generación 293: Fitness = -1
# Generación 294: Fitness = -1
# Generación 295: Fitness = -1
# Generación 296: Fitness = -1
# Generación 297: Fitness = -1
# Generación 298: Fitness = -1
# Generación 299: Fitness = -1
# Generación 300: Fitness = -1
# Generación 301: Fitness = -1
# Generación 302: Fitness = -1
# Generación 303: Fitness = -1
# Generación 304: Fitness = -1
# Generación 305: Fitness = -1
# Generación 306: Fitness = -1
# Generación 307: Fitness = -1
# Generación 308: Fitness = -1
# Generación 309: Fitness = -1
# Generación 310: Fitness = -1
# Generación 311: Fitness = -1
# Generación 312: Fitness = -1
# Generación 313: Fitness = -1
# Generación 314: Fitness = -1
# Generación 315: Fitness = -1
# Generación 316: Fitness = -1
# Generación 317: Fitness = -1
# Generación 318: Fitness = -1
# Generación 319: Fitness = -1
# Generación 320: Fitness = -1
# Generación 321: Fitness = -1
# Generación 322: Fitness = -1
# Generación 323: Fitness = -1
# Generación 324: Fitness = -1
# Generación 325: Fitness = -1
# Generación 326: Fitness = -1
# Generación 327: Fitness = -1
# Generación 328: Fitness = -1
# Generación 329: Fitness = -1
# Generación 330: Fitness = -1
# Generación 331: Fitness = -1
# Generación 332: Fitness = -1
# Generación 333: Fitness = -1
# Generación 334: Fitness = -1
# Generación 335: Fitness = -1
# Generación 336: Fitness = -1
# Generación 337: Fitness = -1
# Generación 338: Fitness = -1
# Generación 339: Fitness = -1
# Generación 340: Fitness = -1
# Generación 341: Fitness = -1
# Generación 342: Fitness = -1
# Generación 343: Fitness = -1
# Generación 344: Fitness = -1
# Generación 345: Fitness = -1
# Generación 346: Fitness = -1
# Generación 347: Fitness = -1
# Generación 348: Fitness = -1
# Generación 349: Fitness = -1
# Generación 350: Fitness = -1
# Generación 351: Fitness = -1
# Generación 352: Fitness = -1
# Generación 353: Fitness = -1
# Generación 354: Fitness = -1
# Generación 355: Fitness = -1
# Generación 356: Fitness = -1
# Generación 357: Fitness = -1
# Generación 358: Fitness = -1
# Generación 359: Fitness = -1
# Generación 360: Fitness = -1
# Generación 361: Fitness = -1
# Generación 362: Fitness = -1
# Generación 363: Fitness = -1
# Generación 364: Fitness = -1
# Generación 365: Fitness = -1
# Generación 366: Fitness = -1
# Generación 367: Fitness = -1
# Generación 368: Fitness = -1
# Generación 369: Fitness = -1
# Generación 370: Fitness = -1
# Generación 371: Fitness = -1
# Generación 372: Fitness = -1
# Generación 373: Fitness = -1
# Generación 374: Fitness = -1
# Generación 375: Fitness = -1
# Generación 376: Fitness = -1
# Generación 377: Fitness = -1
# Generación 378: Fitness = -1
# Generación 379: Fitness = -1
# Generación 380: Fitness = -1
# Generación 381: Fitness = -1
# Generación 382: Fitness = -1
# Generación 383: Fitness = -1
# Generación 384: Fitness = -1
# Generación 385: Fitness = -1
# Generación 386: Fitness = -1
# Generación 387: Fitness = -1
# Generación 388: Fitness = -1
# Generación 389: Fitness = -1
# Generación 390: Fitness = -1
# Generación 391: Fitness = -1
# Generación 392: Fitness = -1
# Generación 393: Fitness = -1
# Generación 394: Fitness = -1
# Generación 395: Fitness = -1
# Generación 396: Fitness = -1
# Generación 397: Fitness = -1
# Generación 398: Fitness = -1
# Generación 399: Fitness = -1
# Generación 400: Fitness = -1
# Generación 401: Fitness = -1
# Generación 402: Fitness = -1
# Generación 403: Fitness = -1
# Generación 404: Fitness = -1
# Generación 405: Fitness = -1
# Generación 406: Fitness = -1
# Generación 407: Fitness = -1
# Generación 408: Fitness = -1
# Generación 409: Fitness = -1
# Generación 410: Fitness = -1
# Generación 411: Fitness = -1
# Generación 412: Fitness = -1
# Generación 413: Fitness = -1
# Generación 414: Fitness = -1
# Generación 415: Fitness = -1
# Generación 416: Fitness = -1
# Generación 417: Fitness = -1
# Generación 418: Fitness = -1
# Generación 419: Fitness = -1
# Generación 420: Fitness = -1
# Generación 421: Fitness = -1
# Generación 422: Fitness = -1
# Generación 423: Fitness = -1
# Generación 424: Fitness = -1
# Generación 425: Fitness = -1
# Generación 426: Fitness = -1
# Generación 427: Fitness = -1
# Generación 428: Fitness = -1
# Generación 429: Fitness = -1
# Generación 430: Fitness = -1
# Generación 431: Fitness = -1
# Generación 432: Fitness = -1
# Generación 433: Fitness = -1
# Generación 434: Fitness = -1
# Generación 435: Fitness = -1
# Generación 436: Fitness = -1
# Generación 437: Fitness = -1
# Generación 438: Fitness = -1
# Generación 439: Fitness = -1
# Generación 440: Fitness = -1
# Generación 441: Fitness = -1
# Generación 442: Fitness = -1
# Generación 443: Fitness = -1
# Generación 444: Fitness = -1
# Generación 445: Fitness = -1
# Generación 446: Fitness = -1
# Generación 447: Fitness = -1
# Generación 448: Fitness = -1
# Generación 449: Fitness = -1
# Generación 450: Fitness = -1
# Generación 451: Fitness = -1
# Generación 452: Fitness = -1
# Generación 453: Fitness = -1
# Generación 454: Fitness = -1
# Generación 455: Fitness = -1
# Generación 456: Fitness = -1
# Generación 457: Fitness = -1
# Generación 458: Fitness = -1
# Generación 459: Fitness = -1
# Generación 460: Fitness = -1
# Generación 461: Fitness = -1
# Generación 462: Fitness = -1
# Generación 463: Fitness = -1
# Generación 464: Fitness = -1
# Generación 465: Fitness = -1
# Generación 466: Fitness = -1
# Generación 467: Fitness = -1
# Generación 468: Fitness = -1
# Generación 469: Fitness = -1
# Generación 470: Fitness = -1
# Generación 471: Fitness = -1
# Generación 472: Fitness = -1
# Generación 473: Fitness = -1
# Generación 474: Fitness = -1
# Generación 475: Fitness = -1
# Generación 476: Fitness = -1
# Generación 477: Fitness = -1
# Generación 478: Fitness = -1
# Generación 479: Fitness = -1
# Generación 480: Fitness = -1
# Generación 481: Fitness = -1
# Generación 482: Fitness = -1
# Generación 483: Fitness = -1
# Generación 484: Fitness = -1
# Generación 485: Fitness = -1
# Generación 486: Fitness = -1
# Generación 487: Fitness = -1
# Generación 488: Fitness = -1
# Generación 489: Fitness = -1
# Generación 490: Fitness = -1
# Generación 491: Fitness = -1
# Generación 492: Fitness = -1
# Generación 493: Fitness = -1
# Generación 494: Fitness = -1
# Generación 495: Fitness = -1
# Generación 496: Fitness = -1
# Generación 497: Fitness = -1
# Generación 498: Fitness = -1
# Generación 499: Fitness = -1
# Generación 500: Fitness = -1
# Generación 501: Fitness = -1
# Generación 502: Fitness = -1
# Generación 503: Fitness = -1
# Generación 504: Fitness = -1
# Generación 505: Fitness = -1
# Generación 506: Fitness = -1
# Generación 507: Fitness = -1
# Generación 508: Fitness = -1
# Generación 509: Fitness = -1
# Generación 510: Fitness = -1
# Generación 511: Fitness = -1
# Generación 512: Fitness = -1
# Generación 513: Fitness = -1
# Generación 514: Fitness = -1
# Generación 515: Fitness = -1
# Generación 516: Fitness = -1
# Generación 517: Fitness = -1
# Generación 518: Fitness = -1
# Generación 519: Fitness = -1
# Generación 520: Fitness = -1
# Generación 521: Fitness = -1
# Generación 522: Fitness = -1
# Generación 523: Fitness = -1
# Generación 524: Fitness = -1
# Generación 525: Fitness = -1
# Generación 526: Fitness = -1
# Generación 527: Fitness = -1
# Generación 528: Fitness = -1
# Generación 529: Fitness = -1
# Generación 530: Fitness = -1
# Generación 531: Fitness = -1
# Generación 532: Fitness = -1
# Generación 533: Fitness = -1
# Generación 534: Fitness = -1
# Generación 535: Fitness = -1
# Generación 536: Fitness = -1
# Generación 537: Fitness = -1
# Generación 538: Fitness = -1
# Generación 539: Fitness = -1
# Generación 540: Fitness = -1
# Generación 541: Fitness = -1
# Generación 542: Fitness = -1
# Generación 543: Fitness = -1
# Generación 544: Fitness = -1
# Generación 545: Fitness = -1
# Generación 546: Fitness = -1
# Generación 547: Fitness = -1
# Generación 548: Fitness = -1
# Generación 549: Fitness = -1
# Generación 550: Fitness = -1
# Generación 551: Fitness = -1
# Generación 552: Fitness = -1
# Generación 553: Fitness = -1
# Generación 554: Fitness = -1
# Generación 555: Fitness = -1
# Generación 556: Fitness = -1
# Generación 557: Fitness = -1
# Generación 558: Fitness = -1
# Generación 559: Fitness = -1
# Generación 560: Fitness = -1
# Generación 561: Fitness = -1
# Generación 562: Fitness = -1
# Generación 563: Fitness = -1
# Generación 564: Fitness = -1
# Generación 565: Fitness = -1
# Generación 566: Fitness = -1
# Generación 567: Fitness = -1
# Generación 568: Fitness = -1
# Generación 569: Fitness = -1
# Generación 570: Fitness = -1
# Generación 571: Fitness = -1
# Generación 572: Fitness = -1
# Generación 573: Fitness = -1
# Generación 574: Fitness = -1
# Generación 575: Fitness = -1
# Generación 576: Fitness = -1
# Generación 577: Fitness = -1
# Generación 578: Fitness = -1
# Generación 579: Fitness = -1
# Generación 580: Fitness = -1
# Generación 581: Fitness = -1
# Generación 582: Fitness = -1
# Generación 583: Fitness = -1
# Generación 584: Fitness = -1
# Generación 585: Fitness = -1
# Generación 586: Fitness = -1
# Generación 587: Fitness = -1
# Generación 588: Fitness = -1
# Generación 589: Fitness = -1
# Generación 590: Fitness = -1
# Generación 591: Fitness = -1
# Generación 592: Fitness = -1
# Generación 593: Fitness = -1
# Generación 594: Fitness = -1
# Generación 595: Fitness = -1
# Generación 596: Fitness = -1
# Generación 597: Fitness = -1
# Generación 598: Fitness = -1
# Generación 599: Fitness = -1
# Generación 600: Fitness = -1
# Generación 601: Fitness = -1
# Generación 602: Fitness = -1
# Generación 603: Fitness = -1
# Generación 604: Fitness = -1
# Generación 605: Fitness = -1
# Generación 606: Fitness = -1
# Generación 607: Fitness = -1
# Generación 608: Fitness = -1
# Generación 609: Fitness = -1
# Generación 610: Fitness = -1
# Generación 611: Fitness = -1
# Generación 612: Fitness = -1
# Generación 613: Fitness = -1
# Generación 614: Fitness = -1
# Generación 615: Fitness = -1
# Generación 616: Fitness = -1
# Generación 617: Fitness = -1
# Generación 618: Fitness = -1
# Generación 619: Fitness = -1
# Generación 620: Fitness = -1
# Generación 621: Fitness = -1
# Generación 622: Fitness = -1
# Generación 623: Fitness = -1
# Generación 624: Fitness = -1
# Generación 625: Fitness = -1
# Generación 626: Fitness = -1
# Generación 627: Fitness = -1
# Generación 628: Fitness = -1
# Generación 629: Fitness = -1
# Generación 630: Fitness = -1
# Generación 631: Fitness = -1
# Generación 632: Fitness = -1
# Generación 633: Fitness = -1
# Generación 634: Fitness = -1
# Generación 635: Fitness = -1
# Generación 636: Fitness = -1
# Generación 637: Fitness = -1
# Generación 638: Fitness = -1
# Generación 639: Fitness = -1
# Generación 640: Fitness = -1
# Generación 641: Fitness = -1
# Generación 642: Fitness = -1
# Generación 643: Fitness = -1
# Generación 644: Fitness = -1
# Generación 645: Fitness = -1
# Generación 646: Fitness = -1
# Generación 647: Fitness = -1
# Generación 648: Fitness = -1
# Generación 649: Fitness = -1
# Generación 650: Fitness = -1
# Generación 651: Fitness = -1
# Generación 652: Fitness = -1
# Generación 653: Fitness = -1
# Generación 654: Fitness = -1
# Generación 655: Fitness = -1
# Generación 656: Fitness = -1
# Generación 657: Fitness = -1
# Generación 658: Fitness = -1
# Generación 659: Fitness = -1
# Generación 660: Fitness = -1
# Generación 661: Fitness = -1
# Generación 662: Fitness = -1
# Generación 663: Fitness = -1
# Generación 664: Fitness = -1
# Generación 665: Fitness = -1
# Generación 666: Fitness = -1
# Generación 667: Fitness = -1
# Generación 668: Fitness = -1
# Generación 669: Fitness = -1
# Generación 670: Fitness = -1
# Generación 671: Fitness = -1
# Generación 672: Fitness = -1
# Generación 673: Fitness = -1
# Generación 674: Fitness = -1
# Generación 675: Fitness = -1
# Generación 676: Fitness = -1
# Generación 677: Fitness = -1
# Generación 678: Fitness = -1
# Generación 679: Fitness = -1
# Generación 680: Fitness = -1
# Generación 681: Fitness = -1
# Generación 682: Fitness = -1
# Generación 683: Fitness = -1
# Generación 684: Fitness = -1
# Generación 685: Fitness = -1
# Generación 686: Fitness = -1
# Generación 687: Fitness = -1
# Generación 688: Fitness = -1
# Generación 689: Fitness = -1
# Generación 690: Fitness = -1
# Generación 691: Fitness = -1
# Generación 692: Fitness = -1
# Generación 693: Fitness = -1
# Generación 694: Fitness = -1
# Generación 695: Fitness = -1
# Generación 696: Fitness = -1
# Generación 697: Fitness = -1
# Generación 698: Fitness = -1
# Generación 699: Fitness = -1
# Generación 700: Fitness = -1
# Generación 701: Fitness = -1
# Generación 702: Fitness = -1
# Generación 703: Fitness = -1
# Generación 704: Fitness = -1
# Generación 705: Fitness = -1
# Generación 706: Fitness = -1
# Generación 707: Fitness = -1
# Generación 708: Fitness = -1
# Generación 709: Fitness = -1
# Generación 710: Fitness = -1
# Generación 711: Fitness = -1
# Generación 712: Fitness = -1
# Generación 713: Fitness = -1
# Generación 714: Fitness = -1
# Generación 715: Fitness = -1
# Generación 716: Fitness = -1
# Generación 717: Fitness = -1
# Generación 718: Fitness = -1
# Generación 719: Fitness = -1
# Generación 720: Fitness = -1
# Generación 721: Fitness = -1
# Generación 722: Fitness = -1
# Generación 723: Fitness = -1
# Generación 724: Fitness = -1
# Generación 725: Fitness = -1
# Generación 726: Fitness = -1
# Generación 727: Fitness = -1
# Generación 728: Fitness = -1
# Generación 729: Fitness = -1
# Generación 730: Fitness = -1
# Generación 731: Fitness = -1
# Generación 732: Fitness = -1
# Generación 733: Fitness = -1
# Generación 734: Fitness = -1
# Generación 735: Fitness = -1
# Generación 736: Fitness = -1
# Generación 737: Fitness = -1
# Generación 738: Fitness = -1
# Generación 739: Fitness = -1
# Generación 740: Fitness = -1
# Generación 741: Fitness = -1
# Generación 742: Fitness = -1
# Generación 743: Fitness = -1
# Generación 744: Fitness = -1
# Generación 745: Fitness = -1
# Generación 746: Fitness = -1
# Generación 747: Fitness = -1
# Generación 748: Fitness = -1
# Generación 749: Fitness = -1
# Generación 750: Fitness = -1
# Generación 751: Fitness = -1
# Generación 752: Fitness = -1
# Generación 753: Fitness = -1
# Generación 754: Fitness = -1
# Generación 755: Fitness = -1
# Generación 756: Fitness = -1
# Generación 757: Fitness = -1
# Generación 758: Fitness = -1
# Generación 759: Fitness = -1
# Generación 760: Fitness = -1
# Generación 761: Fitness = -1
# Generación 762: Fitness = -1
# Generación 763: Fitness = -1
# Generación 764: Fitness = -1
# Generación 765: Fitness = -1
# Generación 766: Fitness = -1
# Generación 767: Fitness = -1
# Generación 768: Fitness = -1
# Generación 769: Fitness = -1
# Generación 770: Fitness = -1
# Generación 771: Fitness = -1
# Generación 772: Fitness = -1
# Generación 773: Fitness = -1
# Generación 774: Fitness = -1
# Generación 775: Fitness = -1
# Generación 776: Fitness = -1
# Generación 777: Fitness = -1
# Generación 778: Fitness = -1
# Generación 779: Fitness = -1
# Generación 780: Fitness = -1
# Generación 781: Fitness = -1
# Generación 782: Fitness = -1
# Generación 783: Fitness = -1
# Generación 784: Fitness = -1
# Generación 785: Fitness = -1
# Generación 786: Fitness = -1
# Generación 787: Fitness = -1
# Generación 788: Fitness = -1
# Generación 789: Fitness = -1
# Generación 790: Fitness = -1
# Generación 791: Fitness = -1
# Generación 792: Fitness = -1
# Generación 793: Fitness = -1
# Generación 794: Fitness = -1
# Generación 795: Fitness = -1
# Generación 796: Fitness = -1
# Generación 797: Fitness = -1
# Generación 798: Fitness = -1
# Generación 799: Fitness = -1
# Generación 800: Fitness = -1
# Generación 801: Fitness = -1
# Generación 802: Fitness = -1
# Generación 803: Fitness = -1
# Generación 804: Fitness = -1
# Generación 805: Fitness = -1
# Generación 806: Fitness = -1
# Generación 807: Fitness = -1
# Generación 808: Fitness = -1
# Generación 809: Fitness = -1
# Generación 810: Fitness = -1
# Generación 811: Fitness = -1
# Generación 812: Fitness = -1
# Generación 813: Fitness = -1
# Generación 814: Fitness = -1
# Generación 815: Fitness = -1
# Generación 816: Fitness = -1
# Generación 817: Fitness = -1
# Generación 818: Fitness = -1
# Generación 819: Fitness = -1
# Generación 820: Fitness = -1
# Generación 821: Fitness = -1
# Generación 822: Fitness = -1
# Generación 823: Fitness = -1
# Generación 824: Fitness = -1
# Generación 825: Fitness = -1
# Generación 826: Fitness = -1
# Generación 827: Fitness = -1
# Generación 828: Fitness = -1
# Generación 829: Fitness = -1
# Generación 830: Fitness = -1
# Generación 831: Fitness = -1
# Generación 832: Fitness = -1
# Generación 833: Fitness = -1
# Generación 834: Fitness = -1
# Generación 835: Fitness = -1
# Generación 836: Fitness = -1
# Generación 837: Fitness = -1
# Generación 838: Fitness = -1
# Generación 839: Fitness = -1
# Generación 840: Fitness = -1
# Generación 841: Fitness = -1
# Generación 842: Fitness = -1
# Generación 843: Fitness = -1
# Generación 844: Fitness = -1
# Generación 845: Fitness = -1
# Generación 846: Fitness = -1
# Generación 847: Fitness = -1
# Generación 848: Fitness = -1
# Generación 849: Fitness = -1
# Generación 850: Fitness = -1
# Generación 851: Fitness = -1
# Generación 852: Fitness = -1
# Generación 853: Fitness = -1
# Generación 854: Fitness = -1
# Generación 855: Fitness = -1
# Generación 856: Fitness = -1
# Generación 857: Fitness = -1
# Generación 858: Fitness = -1
# Generación 859: Fitness = -1
# Generación 860: Fitness = -1
# Generación 861: Fitness = -1
# Generación 862: Fitness = -1
# Generación 863: Fitness = -1
# Generación 864: Fitness = -1
# Generación 865: Fitness = -1
# Generación 866: Fitness = -1
# Generación 867: Fitness = -1
# Generación 868: Fitness = -1
# Generación 869: Fitness = -1
# Generación 870: Fitness = -1
# Generación 871: Fitness = -1
# Generación 872: Fitness = -1
# Generación 873: Fitness = -1
# Generación 874: Fitness = -1
# Generación 875: Fitness = -1
# Generación 876: Fitness = -1
# Generación 877: Fitness = -1
# Generación 878: Fitness = -1
# Generación 879: Fitness = -1
# Generación 880: Fitness = -1
# Generación 881: Fitness = -1
# Generación 882: Fitness = -1
# Generación 883: Fitness = -1
# Generación 884: Fitness = -1
# Generación 885: Fitness = -1
# Generación 886: Fitness = -1
# Generación 887: Fitness = -1
# Generación 888: Fitness = -1
# Generación 889: Fitness = -1
# Generación 890: Fitness = -1
# Generación 891: Fitness = -1
# Generación 892: Fitness = -1
# Generación 893: Fitness = -1
# Generación 894: Fitness = -1
# Generación 895: Fitness = -1
# Generación 896: Fitness = -1
# Generación 897: Fitness = -1
# Generación 898: Fitness = -1
# Generación 899: Fitness = -1
# Generación 900: Fitness = -1
# Generación 901: Fitness = -1
# Generación 902: Fitness = -1
# Generación 903: Fitness = -1
# Generación 904: Fitness = -1
# Generación 905: Fitness = -1
# Generación 906: Fitness = -1
# Generación 907: Fitness = -1
# Generación 908: Fitness = -1
# Generación 909: Fitness = -1
# Generación 910: Fitness = -1
# Generación 911: Fitness = -1
# Generación 912: Fitness = -1
# Generación 913: Fitness = -1
# Generación 914: Fitness = -1
# Generación 915: Fitness = -1
# Generación 916: Fitness = -1
# Generación 917: Fitness = -1
# Generación 918: Fitness = -1
# Generación 919: Fitness = -1
# Generación 920: Fitness = -1
# Generación 921: Fitness = -1
# Generación 922: Fitness = -1
# Generación 923: Fitness = -1
# Generación 924: Fitness = -1
# Generación 925: Fitness = -1
# Generación 926: Fitness = -1
# Generación 927: Fitness = -1
# Generación 928: Fitness = -1
# Generación 929: Fitness = -1
# Generación 930: Fitness = -1
# Generación 931: Fitness = -1
# Generación 932: Fitness = 0
# ¡Solución encontrada!: [4, 0, 7, 3, 1, 6, 2, 5]

# %%
view_solution(solution)
# Out:
# Tablero (representación de filas por columna):
#    0 1 2 3 4 5 6 7
#  0 . . . . Q . . .
#  1 Q . . . . . . .
#  2 . . . . . . . Q
#  3 . . . Q . . . .
#  4 . Q . . . . . .
#  5 . . . . . . Q .
#  6 . . Q . . . . .
#  7 . . . . . Q . .
# Solución (genoma): [4, 0, 7, 3, 1, 6, 2, 5]
