# %%
from graphviz import Digraph

# Clase Grafo Bidireccional con adyacencias
class BidGraphAdj:
  def __init__(self):
    self.adjacencies = {}
  
  def add_node(self, node):
    self.adjacencies[node] = []
  
  def add_edge(self, source, destination, weight):
    if source not in self.adjacencies:
      raise ValueError(f"Source {source} does not exist.")
    if destination not in self.adjacencies:
      raise ValueError(f"Destination {destination} does not exist.")

    # Agregar la conexión del nodo source al nodo destination con su peso
    self.adjacencies[source].append((destination, weight))

    # Agregar la conexión del nodo destination al nodo source con el mismo peso
    self.adjacencies[destination].append((source, weight))
  
  def view(self):
    dot = Digraph(format='png')  # Puedes cambiar el formato según necesites
    for node in self.adjacencies:
      dot.node(node, label=f"{node}\nH:{self.heuristics[node]}")

    for source, edges in self.adjacencies.items():
      for destination, weight in edges:
        dot.edge(source, destination, label=str(weight))

    return dot  # Retorna el objeto Graphviz sin guardarlo

# %%
from graphviz import Digraph

# Clase Grafo Bidireccional con Coordenadas
class BidGraphCoo:
  def __init__(self):
    self.nodes = {} # Almacena nodos con sus coordenadas
    self.edges = [] # Almacena conexiones con pesos

  def add_node(self, node, x, y):
    self.nodes[node] = (x, y)
  
  def view(self):
    dot = Digraph(format='png')
    
    for node, (x, y) in self.nodes.items():
      dot.node(node, label=f"{node}\n({x}, {y})")  # Etiqueta con coordenadas

    for source, destination, weight in self.connections:
      dot.edge(source, destination, label=f"{weight:.2f}")  # Peso con 2 decimales
    
    return dot  # Retorna el objeto Graphviz sin guardarlo

# %%
import random
import math

# Fase 1: Inicializar Temperatura
def inicializar_temperatura():
  return 1000

# Fase 2: Establecer Tour Aleatorio
def generar_tour_aleatorio(grafo):
  nodos = list(grafo.nodes.keys())
  random.shuffle(nodos)
  return nodos

# Fase 3: Inicializar Tours
def inicializar_tours(ciudades):
  tour_actual = generar_tour_aleatorio(ciudades)
  tour_mejor = list(tour_actual)
  return tour_actual, tour_mejor

# Fase 4: Elegir dos nodos
def elegir_dos_nodos(tour):
  i, j = random.sample(range(len(tour)), 2)
  return min(i, j), max(i, j)

# Fase 5: Establecer Nuevo Tour
def nuevo_tour(tour, i, j):
  nuevo = tour[:]
  nuevo[i:j+1] = reversed(nuevo[i:j+1])
  return nuevo

# Fase 6: Energía
def distancia_total(tour, grafo):
  distancia = 0
  for i in range(len(tour)):
    ciudad1 = grafo.nodes[tour[i]]
    ciudad2 = grafo.nodes[tour[(i + 1) % len(tour)]]
    distancia += math.dist(ciudad1, ciudad2)
  return distancia

# Fase 7: Función de Aceptación
def aceptar(energia_actual, energia_nueva, temperatura):
  if energia_nueva < energia_actual:
    return True
  
  probabilidad = math.exp((energia_actual - energia_nueva) / temperatura)
  return random.random() < probabilidad

# Fase 8: El mejor
def actualizar_mejor_tour(tour_actual, tour_mejor, energia_actual, energia_mejor):
  if energia_actual < energia_mejor:
    return list(tour_actual), energia_actual
  
  return tour_mejor, energia_mejor

# Fase 9: Actualizar temperatura
def enfriar(temperatura, factor=0.003):
  return (1 - factor)*temperatura

# Función Principal
def simulated_annealing_grafo(grafo, iteraciones=1000):
  temperatura = inicializar_temperatura()
  tour_actual = generar_tour_aleatorio(grafo)
  tour_mejor = list(tour_actual)
  energia_actual = distancia_total(tour_actual, grafo)
  energia_mejor = energia_actual

  for paso in range(iteraciones):
      i, j = elegir_dos_nodos(tour_actual)
      candidato = nuevo_tour(tour_actual, i, j)
      energia_candidato = distancia_total(candidato, grafo)

      if aceptar(energia_actual, energia_candidato, temperatura):
        tour_actual = candidato
        energia_actual = energia_candidato

      tour_mejor, energia_mejor = actualizar_mejor_tour(
        tour_actual, tour_mejor, energia_actual, energia_mejor
      )

      temperatura = enfriar(temperatura)

      print(f"Iteración {paso} | Mejor distancia: {energia_mejor:.2f}")
      print(f"Tour mejor: {tour_mejor}")

  print("\nMejor tour encontrado:")
  print(tour_mejor)
  print(f"Distancia total: {energia_mejor:.2f}")

  return tour_mejor, energia_mejor

# %%
grafo = BidGraphCoo()
grafo.add_node("Perú", 5, 25)
grafo.add_node("Chile", 10, 5)
grafo.add_node("Colombia", 15, 35)
grafo.add_node("Bolivia", 20, 20)
grafo.add_node("Argentina", 30, 10)
grafo.add_node("Venezuela", 35, 40)
grafo.add_node("Brasil", 40, 25)

simulated_annealing_grafo(grafo)
# Out:
# Iteración 0 | Mejor distancia: 159.64
# Tour mejor: ['Colombia', 'Chile', 'Argentina', 'Brasil', 'Bolivia', 'Perú', 'Venezuela']
# Iteración 1 | Mejor distancia: 159.64
# Tour mejor: ['Colombia', 'Chile', 'Argentina', 'Brasil', 'Bolivia', 'Perú', 'Venezuela']
# Iteración 2 | Mejor distancia: 159.16
# Tour mejor: ['Colombia', 'Perú', 'Bolivia', 'Brasil', 'Venezuela', 'Chile', 'Argentina']
# Iteración 3 | Mejor distancia: 147.82
# Tour mejor: ['Colombia', 'Perú', 'Bolivia', 'Brasil', 'Venezuela', 'Argentina', 'Chile']
# Iteración 4 | Mejor distancia: 147.82
# Tour mejor: ['Colombia', 'Perú', 'Bolivia', 'Brasil', 'Venezuela', 'Argentina', 'Chile']
# Iteración 5 | Mejor distancia: 147.82
# Tour mejor: ['Colombia', 'Perú', 'Bolivia', 'Brasil', 'Venezuela', 'Argentina', 'Chile']
# Iteración 6 | Mejor distancia: 147.82
# Tour mejor: ['Colombia', 'Perú', 'Bolivia', 'Brasil', 'Venezuela', 'Argentina', 'Chile']
# Iteración 7 | Mejor distancia: 146.99
# Tour mejor: ['Perú', 'Colombia', 'Bolivia', 'Argentina', 'Venezuela', 'Brasil', 'Chile']
# Iteración 8 | Mejor distancia: 140.08
# Tour mejor: ['Perú', 'Colombia', 'Brasil', 'Venezuela', 'Argentina', 'Bolivia', 'Chile']
# Iteración 9 | Mejor distancia: 140.08
# Tour mejor: ['Perú', 'Colombia', 'Brasil', 'Venezuela', 'Argentina', 'Bolivia', 'Chile']
# Iteración 10 | Mejor distancia: 140.08
# Tour mejor: ['Perú', 'Colombia', 'Brasil', 'Venezuela', 'Argentina', 'Bolivia', 'Chile']
# Iteración 11 | Mejor distancia: 140.08
# Tour mejor: ['Perú', 'Colombia', 'Brasil', 'Venezuela', 'Argentina', 'Bolivia', 'Chile']
# Iteración 12 | Mejor distancia: 140.08
# Tour mejor: ['Perú', 'Colombia', 'Brasil', 'Venezuela', 'Argentina', 'Bolivia', 'Chile']
# Iteración 13 | Mejor distancia: 140.08
# Tour mejor: ['Perú', 'Colombia', 'Brasil', 'Venezuela', 'Argentina', 'Bolivia', 'Chile']
# Iteración 14 | Mejor distancia: 140.08
# Tour mejor: ['Perú', 'Colombia', 'Brasil', 'Venezuela', 'Argentina', 'Bolivia', 'Chile']
# Iteración 15 | Mejor distancia: 140.08
# Tour mejor: ['Perú', 'Colombia', 'Brasil', 'Venezuela', 'Argentina', 'Bolivia', 'Chile']
# Iteración 16 | Mejor distancia: 140.08
# Tour mejor: ['Perú', 'Colombia', 'Brasil', 'Venezuela', 'Argentina', 'Bolivia', 'Chile']
# Iteración 17 | Mejor distancia: 140.08
# Tour mejor: ['Perú', 'Colombia', 'Brasil', 'Venezuela', 'Argentina', 'Bolivia', 'Chile']
# Iteración 18 | Mejor distancia: 140.08
# Tour mejor: ['Perú', 'Colombia', 'Brasil', 'Venezuela', 'Argentina', 'Bolivia', 'Chile']
# Iteración 19 | Mejor distancia: 140.08
# Tour mejor: ['Perú', 'Colombia', 'Brasil', 'Venezuela', 'Argentina', 'Bolivia', 'Chile']
# Iteración 20 | Mejor distancia: 140.08
# Tour mejor: ['Perú', 'Colombia', 'Brasil', 'Venezuela', 'Argentina', 'Bolivia', 'Chile']
# Iteración 21 | Mejor distancia: 140.08
# Tour mejor: ['Perú', 'Colombia', 'Brasil', 'Venezuela', 'Argentina', 'Bolivia', 'Chile']
# Iteración 22 | Mejor distancia: 140.08
# Tour mejor: ['Perú', 'Colombia', 'Brasil', 'Venezuela', 'Argentina', 'Bolivia', 'Chile']
# Iteración 23 | Mejor distancia: 140.08
# Tour mejor: ['Perú', 'Colombia', 'Brasil', 'Venezuela', 'Argentina', 'Bolivia', 'Chile']
# Iteración 24 | Mejor distancia: 140.08
# Tour mejor: ['Perú', 'Colombia', 'Brasil', 'Venezuela', 'Argentina', 'Bolivia', 'Chile']
# Iteración 25 | Mejor distancia: 140.08
# Tour mejor: ['Perú', 'Colombia', 'Brasil', 'Venezuela', 'Argentina', 'Bolivia', 'Chile']
# Iteración 26 | Mejor distancia: 140.08
# Tour mejor: ['Perú', 'Colombia', 'Brasil', 'Venezuela', 'Argentina', 'Bolivia', 'Chile']
# Iteración 27 | Mejor distancia: 140.08
# Tour mejor: ['Perú', 'Colombia', 'Brasil', 'Venezuela', 'Argentina', 'Bolivia', 'Chile']
# Iteración 28 | Mejor distancia: 140.08
# Tour mejor: ['Perú', 'Colombia', 'Brasil', 'Venezuela', 'Argentina', 'Bolivia', 'Chile']
# Iteración 29 | Mejor distancia: 140.08
# Tour mejor: ['Perú', 'Colombia', 'Brasil', 'Venezuela', 'Argentina', 'Bolivia', 'Chile']
# Iteración 30 | Mejor distancia: 140.08
# Tour mejor: ['Perú', 'Colombia', 'Brasil', 'Venezuela', 'Argentina', 'Bolivia', 'Chile']
# Iteración 31 | Mejor distancia: 140.08
# Tour mejor: ['Perú', 'Colombia', 'Brasil', 'Venezuela', 'Argentina', 'Bolivia', 'Chile']
# Iteración 32 | Mejor distancia: 140.08
# Tour mejor: ['Perú', 'Colombia', 'Brasil', 'Venezuela', 'Argentina', 'Bolivia', 'Chile']
# Iteración 33 | Mejor distancia: 140.08
# Tour mejor: ['Perú', 'Colombia', 'Brasil', 'Venezuela', 'Argentina', 'Bolivia', 'Chile']
# Iteración 34 | Mejor distancia: 139.82
# Tour mejor: ['Argentina', 'Chile', 'Colombia', 'Perú', 'Bolivia', 'Venezuela', 'Brasil']
# Iteración 35 | Mejor distancia: 139.82
# Tour mejor: ['Argentina', 'Chile', 'Colombia', 'Perú', 'Bolivia', 'Venezuela', 'Brasil']
# Iteración 36 | Mejor distancia: 139.82
# Tour mejor: ['Argentina', 'Chile', 'Colombia', 'Perú', 'Bolivia', 'Venezuela', 'Brasil']
# Iteración 37 | Mejor distancia: 139.82
# Tour mejor: ['Argentina', 'Chile', 'Colombia', 'Perú', 'Bolivia', 'Venezuela', 'Brasil']
# Iteración 38 | Mejor distancia: 139.82
# Tour mejor: ['Argentina', 'Chile', 'Colombia', 'Perú', 'Bolivia', 'Venezuela', 'Brasil']
# Iteración 39 | Mejor distancia: 139.82
# Tour mejor: ['Argentina', 'Chile', 'Colombia', 'Perú', 'Bolivia', 'Venezuela', 'Brasil']
# Iteración 40 | Mejor distancia: 139.82
# Tour mejor: ['Argentina', 'Chile', 'Colombia', 'Perú', 'Bolivia', 'Venezuela', 'Brasil']
# Iteración 41 | Mejor distancia: 139.82
# Tour mejor: ['Argentina', 'Chile', 'Colombia', 'Perú', 'Bolivia', 'Venezuela', 'Brasil']
# Iteración 42 | Mejor distancia: 139.82
# Tour mejor: ['Argentina', 'Chile', 'Colombia', 'Perú', 'Bolivia', 'Venezuela', 'Brasil']
# Iteración 43 | Mejor distancia: 139.82
# Tour mejor: ['Argentina', 'Chile', 'Colombia', 'Perú', 'Bolivia', 'Venezuela', 'Brasil']
# Iteración 44 | Mejor distancia: 139.82
# Tour mejor: ['Argentina', 'Chile', 'Colombia', 'Perú', 'Bolivia', 'Venezuela', 'Brasil']
# Iteración 45 | Mejor distancia: 139.82
# Tour mejor: ['Argentina', 'Chile', 'Colombia', 'Perú', 'Bolivia', 'Venezuela', 'Brasil']
# Iteración 46 | Mejor distancia: 139.82
# Tour mejor: ['Argentina', 'Chile', 'Colombia', 'Perú', 'Bolivia', 'Venezuela', 'Brasil']
# Iteración 47 | Mejor distancia: 139.82
# Tour mejor: ['Argentina', 'Chile', 'Colombia', 'Perú', 'Bolivia', 'Venezuela', 'Brasil']
# Iteración 48 | Mejor distancia: 139.82
# Tour mejor: ['Argentina', 'Chile', 'Colombia', 'Perú', 'Bolivia', 'Venezuela', 'Brasil']
# Iteración 49 | Mejor distancia: 139.82
# Tour mejor: ['Argentina', 'Chile', 'Colombia', 'Perú', 'Bolivia', 'Venezuela', 'Brasil']
# Iteración 50 | Mejor distancia: 139.82
# Tour mejor: ['Argentina', 'Chile', 'Colombia', 'Perú', 'Bolivia', 'Venezuela', 'Brasil']
# Iteración 51 | Mejor distancia: 139.82
# Tour mejor: ['Argentina', 'Chile', 'Colombia', 'Perú', 'Bolivia', 'Venezuela', 'Brasil']
# Iteración 52 | Mejor distancia: 139.82
# Tour mejor: ['Argentina', 'Chile', 'Colombia', 'Perú', 'Bolivia', 'Venezuela', 'Brasil']
# Iteración 53 | Mejor distancia: 139.82
# Tour mejor: ['Argentina', 'Chile', 'Colombia', 'Perú', 'Bolivia', 'Venezuela', 'Brasil']
# Iteración 54 | Mejor distancia: 139.82
# Tour mejor: ['Argentina', 'Chile', 'Colombia', 'Perú', 'Bolivia', 'Venezuela', 'Brasil']
# Iteración 55 | Mejor distancia: 139.82
# Tour mejor: ['Argentina', 'Chile', 'Colombia', 'Perú', 'Bolivia', 'Venezuela', 'Brasil']
# Iteración 56 | Mejor distancia: 139.82
# Tour mejor: ['Argentina', 'Chile', 'Colombia', 'Perú', 'Bolivia', 'Venezuela', 'Brasil']
# Iteración 57 | Mejor distancia: 139.82
# Tour mejor: ['Argentina', 'Chile', 'Colombia', 'Perú', 'Bolivia', 'Venezuela', 'Brasil']
# Iteración 58 | Mejor distancia: 139.82
# Tour mejor: ['Argentina', 'Chile', 'Colombia', 'Perú', 'Bolivia', 'Venezuela', 'Brasil']
# Iteración 59 | Mejor distancia: 139.82
# Tour mejor: ['Argentina', 'Chile', 'Colombia', 'Perú', 'Bolivia', 'Venezuela', 'Brasil']
# Iteración 60 | Mejor distancia: 139.82
# Tour mejor: ['Argentina', 'Chile', 'Colombia', 'Perú', 'Bolivia', 'Venezuela', 'Brasil']
# Iteración 61 | Mejor distancia: 139.82
# Tour mejor: ['Argentina', 'Chile', 'Colombia', 'Perú', 'Bolivia', 'Venezuela', 'Brasil']
# Iteración 62 | Mejor distancia: 139.82
# Tour mejor: ['Argentina', 'Chile', 'Colombia', 'Perú', 'Bolivia', 'Venezuela', 'Brasil']
# Iteración 63 | Mejor distancia: 139.82
# Tour mejor: ['Argentina', 'Chile', 'Colombia', 'Perú', 'Bolivia', 'Venezuela', 'Brasil']
# Iteración 64 | Mejor distancia: 139.82
# Tour mejor: ['Argentina', 'Chile', 'Colombia', 'Perú', 'Bolivia', 'Venezuela', 'Brasil']
# Iteración 65 | Mejor distancia: 139.82
# Tour mejor: ['Argentina', 'Chile', 'Colombia', 'Perú', 'Bolivia', 'Venezuela', 'Brasil']
# Iteración 66 | Mejor distancia: 139.82
# Tour mejor: ['Argentina', 'Chile', 'Colombia', 'Perú', 'Bolivia', 'Venezuela', 'Brasil']
# Iteración 67 | Mejor distancia: 139.82
# Tour mejor: ['Argentina', 'Chile', 'Colombia', 'Perú', 'Bolivia', 'Venezuela', 'Brasil']
# Iteración 68 | Mejor distancia: 139.82
# Tour mejor: ['Argentina', 'Chile', 'Colombia', 'Perú', 'Bolivia', 'Venezuela', 'Brasil']
# Iteración 69 | Mejor distancia: 139.82
# Tour mejor: ['Argentina', 'Chile', 'Colombia', 'Perú', 'Bolivia', 'Venezuela', 'Brasil']
# Iteración 70 | Mejor distancia: 139.82
# Tour mejor: ['Argentina', 'Chile', 'Colombia', 'Perú', 'Bolivia', 'Venezuela', 'Brasil']
# Iteración 71 | Mejor distancia: 139.82
# Tour mejor: ['Argentina', 'Chile', 'Colombia', 'Perú', 'Bolivia', 'Venezuela', 'Brasil']
# Iteración 72 | Mejor distancia: 139.82
# Tour mejor: ['Argentina', 'Chile', 'Colombia', 'Perú', 'Bolivia', 'Venezuela', 'Brasil']
# Iteración 73 | Mejor distancia: 139.82
# Tour mejor: ['Argentina', 'Chile', 'Colombia', 'Perú', 'Bolivia', 'Venezuela', 'Brasil']
# Iteración 74 | Mejor distancia: 139.82
# Tour mejor: ['Argentina', 'Chile', 'Colombia', 'Perú', 'Bolivia', 'Venezuela', 'Brasil']
# Iteración 75 | Mejor distancia: 139.82
# Tour mejor: ['Argentina', 'Chile', 'Colombia', 'Perú', 'Bolivia', 'Venezuela', 'Brasil']
# Iteración 76 | Mejor distancia: 139.82
# Tour mejor: ['Argentina', 'Chile', 'Colombia', 'Perú', 'Bolivia', 'Venezuela', 'Brasil']
# Iteración 77 | Mejor distancia: 139.82
# Tour mejor: ['Argentina', 'Chile', 'Colombia', 'Perú', 'Bolivia', 'Venezuela', 'Brasil']
# Iteración 78 | Mejor distancia: 139.82
# Tour mejor: ['Argentina', 'Chile', 'Colombia', 'Perú', 'Bolivia', 'Venezuela', 'Brasil']
# Iteración 79 | Mejor distancia: 139.82
# Tour mejor: ['Argentina', 'Chile', 'Colombia', 'Perú', 'Bolivia', 'Venezuela', 'Brasil']
# Iteración 80 | Mejor distancia: 139.82
# Tour mejor: ['Argentina', 'Chile', 'Colombia', 'Perú', 'Bolivia', 'Venezuela', 'Brasil']
# Iteración 81 | Mejor distancia: 139.82
# Tour mejor: ['Argentina', 'Chile', 'Colombia', 'Perú', 'Bolivia', 'Venezuela', 'Brasil']
# Iteración 82 | Mejor distancia: 139.82
# Tour mejor: ['Argentina', 'Chile', 'Colombia', 'Perú', 'Bolivia', 'Venezuela', 'Brasil']
# Iteración 83 | Mejor distancia: 139.82
# Tour mejor: ['Argentina', 'Chile', 'Colombia', 'Perú', 'Bolivia', 'Venezuela', 'Brasil']
# Iteración 84 | Mejor distancia: 139.82
# Tour mejor: ['Argentina', 'Chile', 'Colombia', 'Perú', 'Bolivia', 'Venezuela', 'Brasil']
# Iteración 85 | Mejor distancia: 139.82
# Tour mejor: ['Argentina', 'Chile', 'Colombia', 'Perú', 'Bolivia', 'Venezuela', 'Brasil']
# Iteración 86 | Mejor distancia: 139.82
# Tour mejor: ['Argentina', 'Chile', 'Colombia', 'Perú', 'Bolivia', 'Venezuela', 'Brasil']
# Iteración 87 | Mejor distancia: 139.82
# Tour mejor: ['Argentina', 'Chile', 'Colombia', 'Perú', 'Bolivia', 'Venezuela', 'Brasil']
# Iteración 88 | Mejor distancia: 139.82
# Tour mejor: ['Argentina', 'Chile', 'Colombia', 'Perú', 'Bolivia', 'Venezuela', 'Brasil']
# Iteración 89 | Mejor distancia: 139.82
# Tour mejor: ['Argentina', 'Chile', 'Colombia', 'Perú', 'Bolivia', 'Venezuela', 'Brasil']
# Iteración 90 | Mejor distancia: 139.82
# Tour mejor: ['Argentina', 'Chile', 'Colombia', 'Perú', 'Bolivia', 'Venezuela', 'Brasil']
# Iteración 91 | Mejor distancia: 139.82
# Tour mejor: ['Argentina', 'Chile', 'Colombia', 'Perú', 'Bolivia', 'Venezuela', 'Brasil']
# Iteración 92 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 93 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 94 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 95 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 96 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 97 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 98 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 99 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 100 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 101 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 102 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 103 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 104 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 105 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 106 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 107 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 108 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 109 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 110 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 111 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 112 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 113 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 114 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 115 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 116 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 117 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 118 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 119 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 120 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 121 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 122 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 123 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 124 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 125 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 126 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 127 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 128 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 129 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 130 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 131 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 132 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 133 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 134 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 135 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 136 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 137 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 138 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 139 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 140 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 141 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 142 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 143 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 144 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 145 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 146 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 147 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 148 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 149 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 150 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 151 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 152 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 153 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 154 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 155 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 156 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 157 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 158 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 159 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 160 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 161 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 162 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 163 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 164 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 165 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 166 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 167 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 168 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 169 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 170 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 171 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 172 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 173 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 174 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 175 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 176 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 177 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 178 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 179 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 180 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 181 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 182 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 183 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 184 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 185 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 186 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 187 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 188 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 189 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 190 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 191 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 192 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 193 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 194 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 195 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 196 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 197 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 198 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 199 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 200 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 201 | Mejor distancia: 127.31
# Tour mejor: ['Bolivia', 'Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Perú']
# Iteración 202 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 203 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 204 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 205 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 206 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 207 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 208 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 209 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 210 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 211 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 212 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 213 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 214 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 215 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 216 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 217 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 218 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 219 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 220 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 221 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 222 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 223 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 224 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 225 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 226 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 227 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 228 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 229 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 230 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 231 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 232 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 233 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 234 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 235 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 236 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 237 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 238 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 239 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 240 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 241 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 242 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 243 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 244 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 245 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 246 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 247 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 248 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 249 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 250 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 251 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 252 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 253 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 254 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 255 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 256 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 257 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 258 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 259 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 260 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 261 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 262 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 263 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 264 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 265 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 266 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 267 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 268 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 269 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 270 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 271 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 272 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 273 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 274 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 275 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 276 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 277 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 278 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 279 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 280 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 281 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 282 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 283 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 284 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 285 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 286 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 287 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 288 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 289 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 290 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 291 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 292 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 293 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 294 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 295 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 296 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 297 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 298 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 299 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 300 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 301 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 302 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 303 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 304 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 305 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 306 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 307 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 308 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 309 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 310 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 311 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 312 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 313 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 314 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 315 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 316 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 317 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 318 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 319 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 320 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 321 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 322 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 323 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 324 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 325 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 326 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 327 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 328 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 329 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 330 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 331 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 332 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 333 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 334 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 335 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 336 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 337 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 338 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 339 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 340 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 341 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 342 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 343 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 344 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 345 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 346 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 347 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 348 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 349 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 350 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 351 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 352 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 353 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 354 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 355 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 356 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 357 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 358 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 359 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 360 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 361 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 362 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 363 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 364 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 365 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 366 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 367 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 368 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 369 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 370 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 371 | Mejor distancia: 123.05
# Tour mejor: ['Colombia', 'Venezuela', 'Brasil', 'Argentina', 'Chile', 'Bolivia', 'Perú']
# Iteración 372 | Mejor distancia: 123.05
# ...
# Iteración 878 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 879 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 880 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 881 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 882 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 883 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 884 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 885 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 886 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 887 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 888 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 889 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 890 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 891 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 892 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 893 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 894 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 895 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 896 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 897 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 898 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 899 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 900 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 901 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 902 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 903 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 904 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 905 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 906 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 907 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 908 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 909 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 910 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 911 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 912 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 913 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 914 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 915 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 916 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 917 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 918 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 919 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 920 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 921 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 922 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 923 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 924 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 925 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 926 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 927 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 928 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 929 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 930 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 931 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 932 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 933 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 934 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 935 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 936 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 937 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 938 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 939 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 940 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 941 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 942 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 943 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 944 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 945 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 946 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 947 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 948 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 949 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 950 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 951 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 952 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 953 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 954 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 955 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 956 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 957 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 958 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 959 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 960 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 961 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 962 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 963 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 964 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 965 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 966 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 967 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 968 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 969 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 970 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 971 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 972 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 973 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 974 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 975 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 976 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 977 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 978 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 979 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 980 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 981 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 982 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 983 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 984 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 985 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 986 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 987 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 988 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 989 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 990 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 991 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 992 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 993 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 994 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 995 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 996 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 997 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 998 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Iteración 999 | Mejor distancia: 121.38
# Tour mejor: ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
#
# Mejor tour encontrado:
# ['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela']
# Distancia total: 121.38
# (['Brasil', 'Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela'],
#  121.38222855912029)

# %%
import math
import random

# Coordenadas de las ciudades (nombre: (x, y))
ciudades = {
    "Perú": (5, 25),
    "Chile": (10, 5),
    "Colombia": (15, 35),
    "Bolivia": (20, 20),
    "Argentina": (30, 10),
    "Venezuela": (35, 40),
    "Brasil": (40, 25)
}

# Función para calcular la distancia entre dos ciudades
def distancia(ciudad1, ciudad2):
    x1, y1 = ciudades[ciudad1]
    x2, y2 = ciudades[ciudad2]
    return math.hypot(x2 - x1, y2 - y1)

# Función para calcular la "energía" de un tour
def calcular_energia(tour):
    return sum(distancia(tour[i], tour[i+1]) for i in range(len(tour)-1)) + distancia(tour[-1], tour[0])

# Función principal del algoritmo de Simulated Annealing
def simulated_annealing(ciudades_dict, temp_inicial=1000, cooling_rate=0.003):
    ciudades_list = list(ciudades_dict.keys())
    current_tour = ciudades_list[:]  # Fase 2: tour aleatorio (o definido)
    random.shuffle(current_tour)

    best_tour = current_tour[:]
    best_energy = calcular_energia(best_tour)
    current_energy = best_energy

    temperature = temp_inicial
    iteration = 0

    while temperature > 1:
        iteration += 1
        # Fase 4: elegir dos nodos
        i, j = sorted(random.sample(range(len(current_tour)), 2))
        new_tour = current_tour[:]
        new_tour[i:j+1] = reversed(new_tour[i:j+1])  # Fase 5

        new_energy = calcular_energia(new_tour)

        # Fase 7: Función de aceptación
        if new_energy < current_energy or random.random() < math.exp((current_energy - new_energy) / temperature):
            current_tour = new_tour
            current_energy = new_energy

            if new_energy < best_energy:
                best_tour = new_tour
                best_energy = new_energy

        # Fase 9: Actualizar temperatura
        temperature *= (1 - cooling_rate)

    return best_tour, best_energy, iteration

# Ejecutar el algoritmo una vez para comparar
resultado = simulated_annealing(ciudades)
print(resultado)
# Out:
# (['Argentina', 'Bolivia', 'Chile', 'Perú', 'Colombia', 'Venezuela', 'Brasil'], 121.38222855912029, 2300)
